# %%
import matplotlib.pyplot as plt 
from automata_1 import Cellular_automata
import numpy as np 

# Parameters 
size = 64
A = 1.0
a = 0.001
h = 0

# %%
#Object constructor
Automata = Cellular_automata(size,A,a,h)

# Make random matrix with 0,1,-1
# And probability p to fin traders
p = 0.5
Automata.make_grid(p)
Automata.show_grid()
# Cluster tagging
Automata.make_clusters()
Automata.show_grid()


# Show the system
#fig,(ax1,ax2) = plt.subplots(1,2)
#ax1.imshow(Automata.grid)
#ax2.imshow(Automata.grid_label)
#plt.show()
# Out:
# state report
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-b7341a3750df> in <module>
#       8 Automata.show_grid()
#       9 # Cluster tagging
# ---> 10 Automata.make_clusters()
#      11 Automata.show_grid()
#      12
#
# ~/Documents/UNAM/Materias/Procesos_estocasticos/Proyecto/automata_1.py in make_clusters(self)
#     153                 # eta lives in [0,spins_numbers in k cluster number :0,k-cluster number]
#     154                 #self.eta = []
# --> 155                 #for k in range(self.n_clusters):
#     156                 #       self.eta.append(np.random.uniform(-1,1,(np.shape(self.index[k])[0],np.shape(self.index[k])[0])))
#     157                 #self.eta = np.array(self.eta)
#
# TypeError: object of type 'zip' has no len()
