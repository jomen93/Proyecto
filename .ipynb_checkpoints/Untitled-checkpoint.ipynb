# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
from scipy import stats

# %%
x = np.loadtxt('x.csv', delimiter=',')
x = x[:-1]
y = np.loadtxt('y.csv', delimiter=',')

data = pd.read_csv("SP500.csv")

# %%
x
# Out:
# array([1.00000000e+00, 1.02882919e+00, 1.05765837e+00, ...,
#        1.33969135e+04, 1.33969423e+04, 1.33969712e+04])

# %%
y
# Out:
# array([1.57287e+05, 0.00000e+00, 0.00000e+00, ..., 0.00000e+00,
#        0.00000e+00, 1.00000e+00])

# %%
plt.plot(x,y,"b.")
plt.ylabel("frecuencia ")
plt.xlabel("Tamaño de cluster")
# Out:
# Text(0.5, 0, 'Tamaño de cluster')

# %%
plt.plot(x,y,"b.")
plt.xscale("log")
plt.yscale("log")
plt.ylabel("$\\rho$")
plt.xlabel("Tamaño de cluster [S]")
plt.title("Distribucion tamaño de cluster")
plt.grid(True)
plt.grid(color='k', alpha=0.5, linestyle='dashed', linewidth=0.9)
plt.plot(0,0,"r-",label = "$\lambda \sim$  "+str(-3.6))
plt.legend()
plt.savefig("potential_law",dpi=1200)
# Out:
# /Users/johan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   # This is added back by InteractiveShellApp.init_path()

# %%
X = np.log(x); Y = np.log(y)
limit =1500

Xp = X[:limit]; Yp = Y[:limit]
index = np.where(Yp == -np.inf)
Yp = np.delete(Yp,index)
Xp = np.delete(Xp,index)



slope1, intercept1, r_value1, p_value1, std_err1 = sp.stats.linregress(Xp,Yp)
plt.plot(X,Y,"b.")
plt.plot(Xp,intercept1 + slope1*Xp,"r-",label = str(slope1))
plt.legend()
plt.grid(color='k', alpha=0.8, linestyle='dashed', linewidth=0.5)
# Out:
# /Users/johan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
X
# Out:
# array([0.        , 0.05611802, 0.10925344, 0.15970737, 0.2077375 ,
#        0.25356607, 0.2973861 , 0.33936628, 0.37965489, 0.418383  ,
#        0.455667  , 0.49161072, 0.52630719, 0.55984008, 0.5922849 ,
#        0.62371005, 0.65417767, 0.6837444 , 0.71246198, 0.74037783,
#        0.76753551, 0.7939751 , 0.81973361, 0.84484525, 0.86934171,
#        0.89325242, 0.91660472, 0.93942412, 0.96173439, 0.98355776,
#        1.00491502, 1.02582567, 1.046308  , 1.06637922, 1.08605549,
#        1.10535207, 1.12428333, 1.14286285, 1.16110345, 1.17901729,
#        1.19661586, 1.21391007, 1.23091026, 1.24762628, 1.26406745,
#        1.28024269, 1.29616044, 1.31182878, 1.32725541, 1.34244767,
#        1.35741257, 1.37215682, 1.38668684, 1.40100875, 1.41512844,
#        1.42905154, 1.44278344, 1.45632933, 1.46969417, 1.48288276,
#        1.49589966, 1.5087493 , 1.52143592, 1.5339636 , 1.54633628,
#        1.55855775, 1.57063165, 1.58256151, 1.59435073, 1.60600257,
#        1.61752022, 1.62890672, 1.64016502, 1.65129798, 1.66230837,
#        1.67319884, 1.68397199, 1.69463032, 1.70517624, 1.7156121 ,
#        1.72594019, 1.73616269, 1.74628175, 1.75629943, 1.76621776,
#        1.77603868, 1.78576409, 1.79539583, 1.80493567, 1.81438537,
#        1.82374661, 1.83302103, 1.84221022, 1.85131574, 1.86033909,
#        1.86928175, 1.87814515, 1.88693068, 1.8956397 , 1.90427352,
#        1.91283344, 1.92132071, 1.92973655, 1.93808215, 1.94635868,
#        1.95456727, 1.96270903, 1.97078504, 1.97879634, 1.98674398,
#        1.99462894, 2.00245222, 2.01021478, 2.01791753, 2.02556141,
#        2.03314731, 2.04067609, 2.04814861, 2.0555657 , 2.06292819,
#        2.07023687, 2.07749252, 2.0846959 , 2.09184777, 2.09894884,
#        2.10599985, 2.11300149, 2.11995445, 2.1268594 , 2.13371699,
#        2.14052788, 2.1472927 , 2.15401206, 2.16068657, 2.16731683,
#        2.17390341, 2.1804469 , 2.18694785, 2.19340681, 2.19982431,
#        2.2062009 , 2.21253708, 2.21883337, 2.22509026, 2.23130825,
#        2.23748781, 2.24362942, 2.24973354, 2.25580063, 2.26183113,
#        2.26782548, 2.27378411, 2.27970745, 2.2855959 , 2.29144989,
#        2.2972698 , 2.30305605, 2.308809  , 2.31452904, 2.32021656,
#        2.3258719 , 2.33149545, 2.33708754, 2.34264854, 2.34817879,
#        2.35367862, 2.35914837, 2.36458836, 2.36999892, 2.37538036,
#        2.38073299, 2.38605713, 2.39135307, 2.39662112, 2.40186155,
#        2.40707467, 2.41226075, 2.41742007, 2.42255292, 2.42765955,
#        2.43274023, 2.43779523, 2.44282481, 2.44782922, 2.45280871,
#        2.45776352, 2.46269391, 2.46760011, 2.47248235, 2.47734087,
#        2.48217591, 2.48698767, 2.4917764 , 2.4965423 , 2.5012856 ,
#        2.5060065 , 2.51070522, 2.51538197, 2.52003694, 2.52467035])

# %%
Y
# Out:
# array([11.96582744, 10.38810266,  9.63436551,  9.1120658 ,  8.57922858,
#         8.24433405,  7.81156849,  7.39510755,  7.00669523,  6.77536609,
#         6.28226675,  5.87493073])

# %%
index = np.where(Y == -np.inf)

# %%
np.delete(X, np.where(Y == -np.inf))
# Out:
# array([0.        , 0.63820407, 1.06394863, 1.36161827, 1.59070682,
#        1.77697217, 1.93393035, 2.06956221, 2.1889759 , 2.29563902,
#        2.39201371, 2.47991132, 2.5607033 , 2.63545305, 2.70500181,
#        2.77002647, 2.83107985, 2.88861922, 2.94302718, 2.99462704,
#        3.04369448, 3.09046651, 3.13514832])

# %%
x_price = np.loadtxt('x_price.csv', delimiter=',')
price = np.loadtxt('price.csv', delimiter=',')
i = 1
plt.plot(x_price[i:],price[i:])

# %%
len(price)
# Out:
# 11

# %%
len(x_price)
# Out:
# 11

# %%
i = 1
plt.plot(x_price[i:],price[i:])

# %% [markdown]
# # Real data

# %%
closure_price = data[data.columns[1]]
closure_price = closure_price.to_numpy().astype(float)

# %% [markdown]
# Function to calculate de the normalized logarithmic returns

# %%
def r_log(price):
    price = price[price > 0]
    P1 = np.roll(price,-1)
    R = np.log(P1)-np.log(price); R = R[:-1]
    r = (R-np.mean(R))/np.std(R)
    return r

# %%
closure_price
# Out:
# array([1050.47, 1062.  , 1055.69, ..., 3122.87, 3112.35, 3193.93])

# %%
plt.plot(closure_price[:1024])

# %%
P = closure_price[:]
P1 = np.roll(P,-1)
R = np.log(P1)-np.log(P); R = R[:-1]

# %%
plt.plot(R)

# %%
r = (R-np.mean(R))/np.std(R)
r
# Out:
# array([ 0.95801127, -0.58546022,  2.61928568, ...,  1.19950852,
#        -0.34903521,  2.32608138])

# %%
plt.plot(r_log(closure_price))

# %%
y, x = np.histogram(r_log(closure_price), bins = len(r_log(closure_price)))
#yp, xp = np.histogram(r_log(price), bins = len(r_log(price)))


x = x[:-1]
plt.plot(x,y,"r.")
#plt.plot(xp,yp,"b+")
#plt.xscale("log")
plt.yscale("log")

# %%
yp, xp = np.histogram(r_log(price), bins = len(r_log(price)))
xp = xp[:-1]
plt.plot(xp,yp,"r.")
#plt.xscale("log")
plt.yscale("log")

# %%
closure_price = closure_price/np.max(closure_price)
price = price/np.max(price)

y, x = np.histogram(r_log(closure_price[:len(price)]), bins = len(r_log(closure_price)))
yp, xp = np.histogram(r_log(price), bins = len(r_log(price)))


x = x[:-1]; xp = xp[:-1]
plt.plot(x,y,"r.",label ="S&P500")
plt.plot(xp,yp,"b+",label = "Modelo")
#plt.xscale("log")
plt.yscale("log")
plt.legend()

# %%
plt.plot(price[price > 0])

# %%
plt.plot(closure_price)

# %%
def autocorr(x):
    result = []
    for i in range(10):
        result.append(x[i+1]*x[i])
    return result

# %%
plt.plot(autocorr(closure_price))

# %%
closure_price[closure_price.size:]
# Out:
# array([], dtype=float64)
